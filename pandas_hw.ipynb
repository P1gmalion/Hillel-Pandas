# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('employee_record.csv', )
df.head()
# Out:
#   first_name last_name  age            position  salary  work_experience
# 0   Jonathan      Paul   25     Product Manager    4440                1
# 1   Brittany    Barker   29       Data Analysts    2357               10
# 2        NaN      Good   30       Data Analysts    3145               11
# 3   Nicholas     Quinn   29  Software Developer    1335               11
# 4    Natasha   Montoya   37         QA Engineer    4964                9

# %%
df = df.dropna()
df.head(20)
# Out:
#    first_name last_name  age             position  salary  work_experience
# 0    Jonathan      Paul   25      Product Manager    4440                1
# 1    Brittany    Barker   29        Data Analysts    2357               10
# 3    Nicholas     Quinn   29   Software Developer    1335               11
# 4     Natasha   Montoya   37          QA Engineer    4964                9
# 5     Mallory   Freeman   30      Project Manager    2068                3
# 6    Victoria   Santana   26   Software Developer    3819               15
# 7       Jason  Sandoval   33      Project Manager     809                8
# 8      Gloria    Harris   26     Python Developer    4527               13
# 9      Edward    Jensen   24    Software Engineer    3381                8
# 10      Jacob       Ray   36          QA Engineer    5180               11
# 11  Christina    Oliver   39      Product Manager    5424                8
# ...

# %%
df.salary.avg()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 df.salary.avg()
#
# File D:\Python\Python_Hillel\Lesson#30\Hillel-Pandas\lib\site-packages\pandas\core\generic.py:5989, in NDFrame.__getattr__(self, name)
#    5982 if (
#    5983     name not in self._internal_names_set
#    5984     and name not in self._metadata
#    5985     and name not in self._accessors
#    5986     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5987 ):
#    5988     return self[name]
# -> 5989 return object.__getattribute__(self, name)
#
# AttributeError: 'Series' object has no attribute 'avg'

# %%
df.salary.sum()
# Out:
# 115465

# %%
df.work_experience.mean()
# Out:
# 8.166666666666666

# %%
df.pivot_table(index='position', columns='age', values='salary', aggfunc='mean')
# Out:
# age                      24      25      26      27      29      30      31
# position
# Data Analysts           NaN     NaN     NaN     NaN  2357.0     NaN     NaN  \
# Front End Developer     NaN     NaN     NaN     NaN     NaN     NaN  2241.0
# Product Manager         NaN  3196.5     NaN     NaN     NaN     NaN     NaN
# Project Manager         NaN     NaN   662.0  5112.0     NaN  2068.0     NaN
# Python Developer        NaN     NaN  4527.0     NaN     NaN     NaN     NaN
# QA Engineer             NaN     NaN     NaN     NaN     NaN     NaN  4603.5
# Software Developer      NaN     NaN  3819.0     NaN  1335.0     NaN     NaN
# Software Engineer    3381.0     NaN  2086.0   503.0     NaN     NaN     NaN
#
# age                      32     33      34  ...      38      39      40
# position                                    ...
# Data Analysts           NaN    NaN     NaN  ...     NaN     NaN     NaN  \
# Front End Developer  2450.0    NaN  3058.0  ...     NaN     NaN     NaN
# ...

# %%
df.pivot_table(index='position', columns='age', values='salary', aggfunc='mean')
# Out:
# age                      24      25      26      27      29      30      31
# position
# Data Analysts           NaN     NaN     NaN     NaN  2357.0     NaN     NaN  \
# Front End Developer     NaN     NaN     NaN     NaN     NaN     NaN  2241.0
# Product Manager         NaN  3196.5     NaN     NaN     NaN     NaN     NaN
# Project Manager         NaN     NaN   662.0  5112.0     NaN  2068.0     NaN
# Python Developer        NaN     NaN  4527.0     NaN     NaN     NaN     NaN
# QA Engineer             NaN     NaN     NaN     NaN     NaN     NaN  4603.5
# Software Developer      NaN     NaN  3819.0     NaN  1335.0     NaN     NaN
# Software Engineer    3381.0     NaN  2086.0   503.0     NaN     NaN     NaN
#
# age                      32     33      34  ...      38      39      40
# position                                    ...
# Data Analysts           NaN    NaN     NaN  ...     NaN     NaN     NaN  \
# Front End Developer  2450.0    NaN  3058.0  ...     NaN     NaN     NaN
# ...

# %%
df.pivot_table(index='salary', columns='age', values='position', aggfunc='mean')
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# File D:\Python\Python_Hillel\Lesson#30\Hillel-Pandas\lib\site-packages\pandas\core\groupby\groupby.py:1490, in GroupBy._cython_agg_general.<locals>.array_func(values)
#    1489 try:
# -> 1490     result = self.grouper._cython_operation(
#    1491         "aggregate",
#    1492         values,
#    1493         how,
#    1494         axis=data.ndim - 1,
#    1495         min_count=min_count,
#    1496         **kwargs,
#    1497     )
#    1498 except NotImplementedError:
#    1499     # generally if we have numeric_only=False
#    1500     # and non-applicable functions
#    1501     # try to python agg
#    1502     # TODO: shouldn't min_count matter?
#
# ...

# %%
df.pivot_table(index='salary', columns='position', values='age', aggfunc='mean')
# Out:
# position  Data Analysts  Front End Developer  Product Manager
# salary
# -4474               NaN                  NaN              NaN  \
# -3202              47.0                  NaN              NaN
#  503                NaN                  NaN              NaN
#  662                NaN                  NaN              NaN
#  809                NaN                  NaN              NaN
#  928                NaN                  NaN              NaN
#  1101               NaN                 32.0              NaN
#  1103               NaN                  NaN              NaN
#  1335               NaN                  NaN              NaN
#  1544               NaN                  NaN              NaN
#  1859               NaN                  NaN              NaN
#  1895               NaN                  NaN             36.0
#  1953               NaN                  NaN             25.0
#  2024               NaN                  NaN             35.0
# ...

# %%
df_chart = df[['age', 'salary']].groupby('age').mean()

# %%
df_chart.plot()
# Out:
# <Axes: xlabel='age'>
